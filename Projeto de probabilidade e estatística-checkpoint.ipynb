# %%
import pandas as pd
import numpy as np
from scipy.stats import binom
from scipy.stats import poisson
from scipy.stats import norm
from scipy.stats import shapiro
from sklearn.linear_model import LinearRegression
import matplotlib.pyplot as plt
from sklearn import datasets
import seaborn as sns

# %%
data = pd.read_csv('Vehicle.csv', header=(0))

# %%
print("Número de linhas e colunas:",data.shape)
data.head(25)
# Out:
# Número de linhas e colunas: (846, 19)
#     Comp  Circ  DCirc  RadRa  PrAxisRa  MaxLRa  ScatRa  Elong  PrAxisRect  \
# 0     95    48     83    178        72      10     162     42          20
# 1     91    41     84    141        57       9     149     45          19
# 2    104    50    106    209        66      10     207     32          23
# 3     93    41     82    159        63       9     144     46          19
# 4     85    44     70    205       103      52     149     45          19
# 5    107    57    106    172        50       6     255     26          28
# 6     97    43     73    173        65       6     153     42          19
# 7     90    43     66    157        65       9     137     48          18
# 8     86    34     62    140        61       7     122     54          17
# 9     93    44     98    197        62      11     183     36          22
# 10    86    36     70    143        61       9     133     50          18
# ...

# %%
data = data.replace('?', np.nan)
data = data.replace('.')
data = data.dropna()
print("Número de linhas e colunas:",data.shape)
data.head(25)
# Out:
# Número de linhas e colunas: (846, 19)
#     Comp  Circ  DCirc  RadRa  PrAxisRa  MaxLRa  ScatRa  Elong  PrAxisRect  \
# 0     95    48     83    178        72      10     162     42          20
# 1     91    41     84    141        57       9     149     45          19
# 2    104    50    106    209        66      10     207     32          23
# 3     93    41     82    159        63       9     144     46          19
# 4     85    44     70    205       103      52     149     45          19
# 5    107    57    106    172        50       6     255     26          28
# 6     97    43     73    173        65       6     153     42          19
# 7     90    43     66    157        65       9     137     48          18
# 8     86    34     62    140        61       7     122     54          17
# 9     93    44     98    197        62      11     183     36          22
# 10    86    36     70    143        61       9     133     50          18
# ...

# %% [markdown]
# # A partir dessa tabela, está tudo arrumado

# %%
data = data.drop_duplicates()
data.head(25)
# Out:
#     Comp  Circ  DCirc  RadRa  PrAxisRa  MaxLRa  ScatRa  Elong  PrAxisRect  \
# 0     95    48     83    178        72      10     162     42          20
# 1     91    41     84    141        57       9     149     45          19
# 2    104    50    106    209        66      10     207     32          23
# 3     93    41     82    159        63       9     144     46          19
# 4     85    44     70    205       103      52     149     45          19
# 5    107    57    106    172        50       6     255     26          28
# 6     97    43     73    173        65       6     153     42          19
# 7     90    43     66    157        65       9     137     48          18
# 8     86    34     62    140        61       7     122     54          17
# 9     93    44     98    197        62      11     183     36          22
# 10    86    36     70    143        61       9     133     50          18
# 11    90    34     66    136        55       6     123     54          17
# ...

# %%
# a)	Média, variância, desvio padrão e mediana para x e y. 
y = data.iloc[:,1]
x = data.iloc[:,9:12]
print(np.mean(x)) #calcula a média de x
print(np.mean(y)) #calcula a média de y
print(np.std(x))#calcula o desvio padrão de x
print(np.std(y))#calcula o desvio padrão de y 
print(np.median(x))# calcula a mediana
print(np.median(y))# calcula a mediana
# Out:
# MaxLRect      147.998818
# ScVarMaxis    188.625296
# ScVarmaxis    439.911348
# dtype: float64
# 44.861702127659576
# MaxLRect       14.507070
# ScVarMaxis     31.376276
# ScVarmaxis    176.588154
# dtype: float64
# 6.166218035141034
# 179.0
# 44.0

# %%
#b)	O histograma de x e y.
#y1
from scipy.stats import normaltest
data = pd.read_csv('Vehicle.csv', header=(0))
significancia = 0.10
data.MaxLRect.hist(bins = 10)
# Out:
# <AxesSubplot:>

# %%
#y2
from scipy.stats import normaltest
data = pd.read_csv('Vehicle.csv', header=(0))
significancia = 0.10
data.ScVarMaxis.hist(bins = 10)
# Out:
# <AxesSubplot:>

# %%
#y3
from scipy.stats import normaltest
data = pd.read_csv('Vehicle.csv', header=(0))
significancia = 0.10
data.ScVarmaxis.hist(bins = 10)
# Out:
# <AxesSubplot:>

# %%
#x
from scipy.stats import normaltest
data = pd.read_csv('Vehicle.csv', header=(0))
significancia = 0.10
data.Circ.hist(bins = 10)
# Out:
# <AxesSubplot:>

# %%
#c)	O boxplot de x e y.
import seaborn as sns
sns.set(style="whitegrid")
ax = sns.boxplot(y)
# Out:
# C:\Users\Vitor\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
#d)	O coeficiente de correlação de x e y.
y = data.iloc[:,1]
x = data.iloc[:,9:12]
X = np.array(x).reshape(-1, 1)
y = np.array(y)
modelo = LinearRegression().fit(x, y)
print(modelo.intercept_)
print (modelo.coef_)
from sklearn.metrics import r2_score
R2 = r2_score(y, modelo.predict(x))
print('R2:', R2)
# Out:
# -9.78829894978314
# [0.33490159 0.01439159 0.00538823]
# R2: 0.9517287941450917

# %%
# Verificação atrav´s do histograma
plt.hist(x, bins = 'auto')
plt.title('Dados')
plt.ylabel('Frequência')
plt.xlabel('Valores')
plt.show()

# %%
#e)	Fazer o teste de normalidade para  y e x.
data = pd.read_csv('Vehicle.csv', header=(0))
data = data.to_numpy()
# normalidade test
stat, p = shapiro(x)
print('Statistics=%.3f, p=%.3f' % (stat, p))
# interpretação
alpha = 0.05
if p > alpha:
    print('Amostra Gaussiana (aceita H0)')
else:
    print('Amostra não Gausssiana (rejeita H0)')
# Out:
# Statistics=0.735, p=0.000
# Amostra não Gausssiana (rejeita H0)

# %%
#y1
data = pd.read_csv('Vehicle.csv', header=(0))
from scipy.stats import normaltest
significancia = 0.10
data.MaxLRect.hist(bins = 10)
# Out:
# <AxesSubplot:>

# %%
stat_test, p_valor = normaltest(data.MaxLRect)
print(stat_test)
print(p_valor)
# Out:
# 68.99457013124207
# 1.0423641237748946e-15

# %%
resultado=p_valor<=significancia

# %%
print("Rejeitamos a hipotese nula:", resultado)
# Out:
# Rejeitamos a hipotese nula: True

# %%
#y2
from scipy.stats import normaltest
significancia = 0.10
data.ScVarMaxis.hist(bins = 10)
# Out:
# <AxesSubplot:>

# %%
stat_test, p_valor = normaltest(data.ScVarMaxis)
print(stat_test)
print(p_valor)
# Out:
# 51.76323564354779
# 5.7511698952333535e-12

# %%
resultado=p_valor<=significancia

# %%
print("Rejeitamos a hipotese nula:", resultado)
# Out:
# Rejeitamos a hipotese nula: True

# %%
#y3
from scipy.stats import normaltest
significancia = 0.10
data.ScVarmaxis.hist(bins = 10)
# Out:
# <AxesSubplot:>

# %%
stat_test, p_valor = normaltest(data.ScVarmaxis)
print(stat_test)
print(p_valor)
# Out:
# 79.20265542669604
# 6.329390604716024e-18

# %%
resultado=p_valor<=significancia

# %%
print("Rejeitamos a hipotese nula:", resultado)
# Out:
# Rejeitamos a hipotese nula: True

# %%
#x
from scipy.stats import normaltest
significancia = 0.10
data.Circ.hist(bins = 10)
# Out:
# <AxesSubplot:>

# %%
stat_test, p_valor = normaltest(data.Circ)
print(stat_test)
print(p_valor)
# Out:
# 133.43573044457528
# 1.0587643012210313e-29

# %%
resultado=p_valor<=significancia

# %%
print("Rejeitamos a hipotese nula:", resultado)
# Out:
# Rejeitamos a hipotese nula: True

# %%
#f)	Fazer o gráfico de densidade junto com o histograma para as variáveis x e y.
y = data.iloc[:,1]
x = data.iloc[:,9:12]
plt.hist(x, bins = 'auto')
plt.title('Dados')
plt.ylabel('Frequência')
plt.xlabel('Valores')
plt.show()
plt.hist(y, bins = 'auto')
plt.title('Dados')
plt.ylabel('Frequência')
plt.xlabel('Valores')
plt.show()
